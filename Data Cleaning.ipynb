# %% [markdown]
# Importing python libraries to be used:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# There are 8 different csv files regarding each year.
# <br>To make full analysis throughout 2015-2022, I am going to join each file into main dataframe using 'for in' loop.

# %%
#names of csv source files
years = ['2015','2016','2017','2018','2019','2020','2021','2022']

# %%
main_df = pd.DataFrame(pd.read_csv(r"./source_files/2015.csv"))
main_df['Year'] = '2015'
for i in range(1, len(years)):
    sub_df = pd.read_csv(r"./source_files/"+years[i]+r".csv")
    sub_df['Year'] = years[i]
    main_df = pd.concat([main_df,sub_df],axis=0)
    main_df = main_df.reset_index(drop=True)
main_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe             1.0            7.587
# 1      Iceland  Western Europe             2.0            7.561
# 2      Denmark  Western Europe             3.0            7.527
# 3       Norway  Western Europe             4.0            7.522
# 4       Canada   North America             5.0            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  ...  \
# 0                   0.94143  0.66557                        0.41978  ...
# 1                   0.94784  0.62877                        0.14145  ...
# ...

# %% [markdown]
# Let's see what the dataframe looks like:

# %%
main_df.shape
# Out:
# (1231, 57)

# %% [markdown]
# The df has 1231 rows and 57 columns.
# <br>The number of columns isn't expected. This might mean that the attributes of each subset of data have different naming so they were added as separate columns.
# <br>Let's have a look at the columns:

# %%
#how many columns each csv has
column_check = {}

column_check = {years[i] : pd.read_csv(r"./source_files/"+years[i]+r".csv").shape[1] for i in range(0, len(years))} #using 1st index of attribute 'shape' which is number of columns
print(column_check)
# Out:
# {'2015': 12, '2016': 13, '2017': 12, '2018': 9, '2019': 9, '2020': 20, '2021': 20, '2022': 12}

# %%
#how the columns are named
main_df.columns.sort_values()
# Out:
# Index(['Country', 'Country name', 'Country or region',
#        'Dystopia (1.83) + residual', 'Dystopia + residual',
#        'Dystopia Residual', 'Dystopia.Residual', 'Economy (GDP per Capita)',
#        'Economy..GDP.per.Capita.',
#        'Explained by: Freedom to make life choices',
#        'Explained by: GDP per capita', 'Explained by: Generosity',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Log GDP per capita',
#        'Explained by: Perceptions of corruption',
#        'Explained by: Social support', 'Family', 'Freedom',
#        'Freedom to make life choices', 'Freedom to make life choices_',
#        'GDP per capita', 'Generosity', 'Generosity_', 'Happiness Rank',
#        'Happiness Score', 'Happiness score', 'Happiness.Rank',
#        'Happiness.Score', 'Health (Life Expectancy)',
#        'Health..Life.Expectancy.', 'Healthy life expectancy',
#        'Healthy life expectancy_', 'Ladder score', 'Ladder score in Dystopia',
# ...

# %% [markdown]
# There is significant redundancy in the columns.
# <br>For example, information about countries is split into three columns:
# * Country
# * Country name
# * Country or region
# <br> The files have between 9-20 columns. Let's have deeper look into 2020 and 2021 as they have much more columns than the rest of subsets:

# %%
for i in range(5, 6): #(5,6) are indexes of years list: 2020 and 2021 
    df_20_21 = pd.read_csv(r"./source_files/"+years[i]+r".csv")
df_20_21.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support_', 'Healthy life expectancy_',
#        'Freedom to make life choices_', 'Generosity_',
#        'Perceptions of corruption_', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %% [markdown]
# As suspected, these years contain duplicated columns of six happiness factors. Let's compare ranges of these factors:

# %%
df_20_21[['Logged GDP per capita',
'Explained by: Log GDP per capita',
'Social support_',
'Explained by: Social support',
'Healthy life expectancy_',
 'Explained by: Healthy life expectancy',
 'Freedom to make life choices_',
 'Explained by: Freedom to make life choices',
 'Generosity_','Explained by: Generosity',
 'Perceptions of corruption_','Explained by: Perceptions of corruption']].describe()
# Out:
#        Logged GDP per capita  Explained by: Log GDP per capita  \
# count             153.000000                        153.000000
# mean                9.295706                          0.868771
# std                 1.201588                          0.372416
# min                 6.492642                          0.000000
# 25%                 8.350645                          0.575862
# 50%                 9.456313                          0.918549
# 75%                10.265124                          1.169229
# max                11.450681                          1.536676
#
#        Social support_  Explained by: Social support  \
# count       153.000000                    153.000000
# mean          0.808721                      1.155607
# std           0.121453                      0.286866
# min           0.319460                      0.000000
# 25%           0.737217                      0.986718
# 50%           0.829204                      1.203987
# ...

# %% [markdown]
# According to the report documentation, compared columns on the right are modified data used as final output in all other data files. To avoid discrepancies in data ranges, I will use columns to the right.
# <br>Our final column adjustment looks as below:

# %%
correct_names = {
'Country name': 'Country',
'Country or region': 'Country',
'Dystopia (1.83) + residual': 'Dystopia Residual',
'Dystopia + residual': 'Dystopia Residual',
'Dystopia.Residual': 'Dystopia Residual',
'Economy (GDP per Capita)': 'GDP per Capita',
'Economy..GDP.per.Capita.': 'GDP per Capita',
'Explained by: Freedom to make life choices': 'Freedom to Make Life Choices',
'Explained by: GDP per capita': 'GDP per Capita',
'Explained by: Generosity': "Generosity",
'Explained by: Healthy life expectancy': 'Healthy Life Expectancy',
'Explained by: Log GDP per capita': 'GDP per Capita',
'Explained by: Perceptions of corruption' : 'Corruption Perception',
'Explained by: Social support': 'Social Support',
'Family': 'Social Support',
'Freedom': 'Freedom to Make Life Choices',
'Freedom to make life choices': 'Freedom to Make Life Choices',
'GDP per capita': 'GDP per Capita',
'Happiness score': 'Happiness Score',
'Happiness.Rank': 'Happiness Rank',
'Happiness.Score': 'Happiness Score',
'Health (Life Expectancy)': 'Healthy Life Expectancy',
'Health..Life.Expectancy.': 'Healthy Life Expectancy',
'Healthy life expectancy': 'Healthy Life Expectancy',
'Ladder score': 'Happiness Score',
'Overall rank': 'Happiness Rank',
'Perceptions of corruption': 'Corruption Perception',
'RANK': 'Happiness Rank',
'Regional indicator': 'Region',
'Score': 'Happiness Score',
'Social support': 'Social Support',
'Trust (Government Corruption)': 'Corruption Perception',
'Trust..Government.Corruption.': 'Corruption Perception'
}

# %% [markdown]
# The columns have finally equalized names. However, each year has them as separate columns which needs to be fixed.

# %%
main_df = main_df.rename(columns=correct_names)
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1231 entries, 0 to 1230
# Data columns (total 57 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Country                         617 non-null    object
#  1   Region                          315 non-null    object
#  2   Happiness Rank                  315 non-null    float64
#  3   Happiness Score                 315 non-null    float64
#  4   Standard Error                  158 non-null    float64
#  5   GDP per Capita                  315 non-null    float64
#  6   Social Support                  470 non-null    float64
#  7   Healthy Life Expectancy         315 non-null    float64
#  8   Freedom to Make Life Choices    470 non-null    float64
#  9   Corruption Perception           315 non-null    float64
#  10  Generosity                      782 non-null    float64
#  11  Dystopia Residual               315 non-null    float64
# ...

# %% [markdown]
# The easiest method would be using concatenating code used earlier with addition of renaming columns while joining.
# <br>It's time to focus on data inside.
# <br>
# <br>Having looked at main_df's tail:
# <br>#1 There is unnecessary 1230th row which needs to be dropped.
# <br>#2 Some countries have unnecessary asterix (*) which could disrupt the data and needs to be removed.

# %%
main_df = pd.DataFrame(pd.read_csv(r"./source_files/2015.csv"))
main_df = main_df.rename(columns=correct_names)
main_df['Year'] = '2015'

for i in range(1, len(years)):
    sub_df = pd.read_csv(r"./source_files/"+years[i]+r".csv")
    sub_df = sub_df.rename(columns=correct_names)
    sub_df['Year'] = years[i]
    main_df = pd.concat([main_df,sub_df],axis=0)
    main_df = main_df.reset_index(drop=True)

main_df['Year'] = main_df['Year'].astype(int)
main_df #it allows us to see both head and tail of the dataframe
# Out:
#           Country          Region  Happiness Rank  Happiness Score  \
# 0     Switzerland  Western Europe             1.0            7.587
# 1         Iceland  Western Europe             2.0            7.561
# 2         Denmark  Western Europe             3.0            7.527
# 3          Norway  Western Europe             4.0            7.522
# 4          Canada   North America             5.0            7.427
# ...           ...             ...             ...              ...
# 1226      Rwanda*             NaN           143.0            3.268
# 1227     Zimbabwe             NaN           144.0            2.995
# 1228      Lebanon             NaN           145.0            2.955
# 1229  Afghanistan             NaN           146.0            2.404
# 1230           xx             NaN           147.0              NaN
#
#       Standard Error  GDP per Capita  Social Support  Healthy Life Expectancy  \
# 0            0.03411         1.39651         1.34951                  0.94143
# ...

# %% [markdown]
# Number of columns is reduced to 29.
# <br>Having looked at main_df.info:
# <br>#1 I only need first 12 columns, with Years included. The rest can be omitted.
# <br>#2 I won't need Standard Error column (4th index).
# <br>#3 Region and Happiness Rank columns have null values.
# * Happiness Rank can be easily calculated based on Happiness Score of the countries (which thankfully there's no null values)
# * Region could be retrieved based on data from other years (none of the countries have moved anywhere and changed their region, I suppose...)

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1231 entries, 0 to 1230
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Country                         1231 non-null   object
#  1   Region                          617 non-null    object
#  2   Happiness Rank                  929 non-null    float64
#  3   Happiness Score                 1230 non-null   float64
#  4   Standard Error                  158 non-null    float64
#  5   GDP per Capita                  1230 non-null   float64
#  6   Social Support                  1230 non-null   float64
#  7   Healthy Life Expectancy         1230 non-null   float64
#  8   Freedom to Make Life Choices    1230 non-null   float64
#  9   Corruption Perception           1229 non-null   float64
#  10  Generosity                      1230 non-null   float64
#  11  Dystopia Residual               918 non-null    float64
# ...

# %%
#reducing columns - from 1st to 'Year'
cut_df = main_df.loc[:,:'Year']

#getting rid of Standard Error column and the last row
cut_df = cut_df.drop(columns='Standard Error')
cut_df = cut_df.drop(axis=0, index=1230)

#replacing null value by country Emirates mean of Corruption Perception column
emirates = cut_df[cut_df['Country'].str.contains('Emirates')]
cut_df['Corruption Perception'] = cut_df['Corruption Perception'].fillna(emirates['Corruption Perception'].mean())

#getting rid of asterix from countries' names
cut_df['Country'] = cut_df['Country'].str.replace('*','', regex=True)

cut_df.tail()
# Out:
#           Country Region  Happiness Rank  Happiness Score  GDP per Capita  \
# 1225     Botswana    NaN           142.0            3.471           1.503
# 1226       Rwanda    NaN           143.0            3.268           0.001
# 1227     Zimbabwe    NaN           144.0            2.995           0.001
# 1228      Lebanon    NaN           145.0            2.955           1.392
# 1229  Afghanistan    NaN           146.0            2.404           0.001
#
#       Social Support  Healthy Life Expectancy  Freedom to Make Life Choices  \
# 1225           0.001                    0.280                         0.571
# 1226           0.000                    0.462                         0.621
# 1227           0.001                    0.270                         0.329
# 1228           0.000                    0.631                         0.103
# 1229           0.000                    0.289                         0.000
#
# ...

# %% [markdown]
# Let's focus on null values on Region and Happiness Rank.
# <br>We clearly see that 2017-2019 and 2022 are missing data on Region and 2020-2021 are missing data on Happiness Rank:

# %%
counted_by_year = cut_df.groupby('Year').count()
counted_by_year
# Out:
#       Country  Region  Happiness Rank  Happiness Score  GDP per Capita  \
# Year
# 2015      158     158             158              158             158
# 2016      157     157             157              157             157
# 2017      155       0             155              155             155
# 2018      156       0             156              156             156
# 2019      156       0             156              156             156
# 2020      153     153               0              153             153
# 2021      149     149               0              149             149
# 2022      146       0             146              146             146
#
#       Social Support  Healthy Life Expectancy  Freedom to Make Life Choices  \
# Year
# 2015             158                      158                           158
# 2016             157                      157                           157
# 2017             155                      155                           155
# ...

# %%
#checking indexing of 2020-2021 years - 782:1083
missing_rank = cut_df[cut_df.Year.isin([2020,2021])]
missing_rank
# Out:
#           Country              Region  Happiness Rank  Happiness Score  \
# 782       Finland      Western Europe             NaN           7.8087
# 783       Denmark      Western Europe             NaN           7.6456
# 784   Switzerland      Western Europe             NaN           7.5599
# 785       Iceland      Western Europe             NaN           7.5045
# 786        Norway      Western Europe             NaN           7.4880
# ...           ...                 ...             ...              ...
# 1079      Lesotho  Sub-Saharan Africa             NaN           3.5120
# 1080     Botswana  Sub-Saharan Africa             NaN           3.4670
# 1081       Rwanda  Sub-Saharan Africa             NaN           3.4150
# 1082     Zimbabwe  Sub-Saharan Africa             NaN           3.1450
# 1083  Afghanistan          South Asia             NaN           2.5230
#
#       GDP per Capita  Social Support  Healthy Life Expectancy  \
# ...

# %%
#calculating Happiness Rank by grouping Happiness Score in descending order 
missing_rank['Happiness Rank'] = missing_rank.groupby('Year')['Happiness Score'].rank('dense',ascending=False)
missing_rank
cut_df.loc[782:1083,'Happiness Rank'] = missing_rank['Happiness Rank']
cut_df[cut_df.Year.isin([2020,2021])]
# Out:
# C:\Users\Agata\AppData\Local\Temp\ipykernel_2852\1278463174.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   missing_rank['Happiness Rank'] = missing_rank.groupby('Year')['Happiness Score'].rank('dense',ascending=False)
#           Country              Region  Happiness Rank  Happiness Score  \
# 782       Finland      Western Europe             1.0           7.8087
# 783       Denmark      Western Europe             2.0           7.6456
# 784   Switzerland      Western Europe             3.0           7.5599
# 785       Iceland      Western Europe             4.0           7.5045
# 786        Norway      Western Europe             5.0           7.4880
# ...           ...                 ...             ...              ...
# ...

# %% [markdown]
# Happiness Rank is fixed. Let's dive in the Region column to see if the naming is consistent among the years and if not, to pick one year which we'll use as a base for all rows:

# %%
#checking if the Region values are the same of different among years
region_naming = cut_df.groupby('Year')['Region'].unique()
pd.set_option('display.max_colwidth', 300)
region_naming
# Out:
# Year
# 2015         [Western Europe, North America, Australia and New Zealand, Middle East and Northern Africa, Latin America and Caribbean, Southeastern Asia, Central and Eastern Europe, Eastern Asia, Sub-Saharan Africa, Southern Asia]
# 2016         [Western Europe, North America, Australia and New Zealand, Middle East and Northern Africa, Latin America and Caribbean, Southeastern Asia, Central and Eastern Europe, Eastern Asia, Sub-Saharan Africa, Southern Asia]
# 2017                                                                                                                                                                                                                            [nan]
# 2018                                                                                                                                                                                                                            [nan]
# ...

# %% [markdown]
# 2015-2016 and 2020-2021 regions are named differenly.
# <br>I chose the first option to be used in my final dataset:

# %%
#checking indexing of 2015 - 0:157
cut_df[cut_df.Year.isin([2015])]
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe             1.0
# 1        Iceland                   Western Europe             2.0
# 2        Denmark                   Western Europe             3.0
# 3         Norway                   Western Europe             4.0
# 4         Canada                    North America             5.0
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa           154.0
# 154        Benin               Sub-Saharan Africa           155.0
# 155        Syria  Middle East and Northern Africa           156.0
# 156      Burundi               Sub-Saharan Africa           157.0
# 157         Togo               Sub-Saharan Africa           158.0
#
#      Happiness Score  GDP per Capita  Social Support  Healthy Life Expectancy  \
# 0              7.587         1.39651         1.34951                  0.94143
# ...

# %%
c = cut_df.loc[0:157].Country.tolist()
r = cut_df.loc[0:157].Region.tolist()
region = {c[i] : r[i] for i in range(len(c))} #2015 'country : region' dictionary to be used in all years

cut_df['Region'] = cut_df.Country.map(region)
cut_df
# Out:
#           Country                           Region  Happiness Rank  \
# 0     Switzerland                   Western Europe             1.0
# 1         Iceland                   Western Europe             2.0
# 2         Denmark                   Western Europe             3.0
# 3          Norway                   Western Europe             4.0
# 4          Canada                    North America             5.0
# ...           ...                              ...             ...
# 1225     Botswana               Sub-Saharan Africa           142.0
# 1226       Rwanda               Sub-Saharan Africa           143.0
# 1227     Zimbabwe               Sub-Saharan Africa           144.0
# 1228      Lebanon  Middle East and Northern Africa           145.0
# 1229  Afghanistan                    Southern Asia           146.0
#
#       Happiness Score  GDP per Capita  Social Support  \
# 0               7.587         1.39651         1.34951
# ...

# %% [markdown]
# There are still countries with missing Region. I checked each of below whether that was caused by different naming or missing region in 2015 year:

# %%
cut_df[cut_df['Region'].isna()].Country.unique()
# Out:
# array(['Puerto Rico', 'Belize', 'Somalia', 'Somaliland Region', 'Namibia',
#        'South Sudan', 'Taiwan Province of China',
#        'Hong Kong S.A.R., China', 'Trinidad & Tobago', 'Northern Cyprus',
#        'North Macedonia', 'Gambia', 'Hong Kong S.A.R. of China',
#        'Maldives', 'Czechia', 'Congo', 'Eswatini. Kingdom of'],
#       dtype=object)

# %%
#updating names on countries that had different naming throughout years 
country_correction = {
    'Somaliland Region': 'Somaliland region',
    'Taiwan Province of China': 'Taiwan',
    'Hong Kong S.A.R., China': 'Hong Kong',
    'Trinidad & Tobago': 'Trinidad and Tobago',
    'Northern Cyprus': 'North Cyprus',
    'North Macedonia': 'Macedonia',
    'Hong Kong S.A.R. of China': 'Hong Kong',
    'Czechia': 'Czech Republic'
}
cut_df['Country'] = cut_df.Country.replace(country_correction)

#updating missing region
region_correction = {
    'Puerto Rico': 'Latin America and Caribbean',
    'Belize': 'Latin America and Caribbean',
    'Somalia': 'Sub-Saharan Africa',
    'Namibia': 'Sub-Saharan Africa',
    'South Sudan': 'Sub-Saharan Africa',
    'Gambia': 'Sub-Saharan Africa',
    'Maldives': 'Southern Asia',
    'Congo': 'Sub-Saharan Africa',
    'Eswatini. Kingdom of': 'Sub-Saharan Africa'
}
region.update(region_correction)
cut_df['Region'] = cut_df.Country.map(region)

# %% [markdown]
# The dataset looks much better.
# <br>The only null values are Region and Dystopia Residual which means they weren't there in the first place.

# %%
cut_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230 entries, 0 to 1229
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       1230 non-null   object
#  1   Region                        1230 non-null   object
#  2   Happiness Rank                1230 non-null   float64
#  3   Happiness Score               1230 non-null   float64
#  4   GDP per Capita                1230 non-null   float64
#  5   Social Support                1230 non-null   float64
#  6   Healthy Life Expectancy       1230 non-null   float64
#  7   Freedom to Make Life Choices  1230 non-null   float64
#  8   Corruption Perception         1230 non-null   float64
#  9   Generosity                    1230 non-null   float64
#  10  Dystopia Residual             918 non-null    float64
#  11  Year                          1230 non-null   int32
# ...

# %% [markdown]
# The dataset is ready to be statistically explored.

# %%
cut_df.to_csv(r'./cleaned_data.csv', index=False)
